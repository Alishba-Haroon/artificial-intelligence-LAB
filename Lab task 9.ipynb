# %% [markdown]
# # Libraries

# %%
import pandas as pd

# %% [markdown]
# # Data Loading / Reading

# %%
# loading the dataset into Python environment
df = pd.read_csv(r"File Path")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th              7.0
# 1       38       Private   89814       HS-grad              9.0
# 2       28     Local-gov  336951    Assoc-acdm              NaN
# 3       44       Private  160323  Some-college              NaN
# 4       18           NaN  103497  Some-college              NaN
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm             12.0
# 48838   40       Private  154374       HS-grad              9.0
# 48839   58       Private  151910       HS-grad              9.0
# 48840   22       Private  201490       HS-grad              9.0
# 48841   52  Self-emp-inc  287927       HS-grad              9.0
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child    NaN    Male
# ...

# %% [markdown]
# # Data Exploration

# %%
#View the First Five Rows, preview the data and get a sense of its structure
df.head(5)
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th              7.0       Never-married
# 1   38    Private   89814       HS-grad              9.0  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm              NaN  Married-civ-spouse
# 3   44    Private  160323  Some-college              NaN  Married-civ-spouse
# 4   18        NaN  103497  Some-college              NaN       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child    NaN    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
# View the last Five Rows
df.tail(5)
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm             12.0
# 48838   40       Private  154374     HS-grad              9.0
# 48839   58       Private  151910     HS-grad              9.0
# 48840   22       Private  201490     HS-grad              9.0
# 48841   52  Self-emp-inc  287927     HS-grad              9.0
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
# show the total number of columns or rows
print(f"Total numbers of Rows: {df.shape[0]} \nTotal numbers of Columns: {df.shape[1]}")
# Out:
# Total numbers of Rows: 48842
# Total numbers of Columns: 15

# %%
# Identify missing values
df.isnull().sum()
# Out:
# age                0
# workclass          3
# fnlwgt             0
# education          0
# educational-num    5
# marital-status     0
# occupation         0
# relationship       0
# race               4
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# counts non-null values in each column
df.count()
# Out:
# age                48842
# workclass          48839
# fnlwgt             48842
# education          48842
# educational-num    48837
# marital-status     48842
# occupation         48842
# relationship       48842
# race               48838
# gender             48842
# capital-gain       48842
# capital-loss       48842
# hours-per-week     48842
# native-country     48842
# income             48842
# dtype: int64

# %%
# Use for basic statistics on numerical columns, like mean, median, and standard deviation
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48837.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078199   1079.067626
# std       13.710510  1.056040e+05         2.570938   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# Get an overview of the data, including the count of entries, data types of each column and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48839 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48837 non-null  float64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48838 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 5.6+ MB

# %%
# Useful for listing all column names in the dataset
for i in df.columns:
    print(i)
# Out:
# age
# workclass
# fnlwgt
# education
# educational-num
# marital-status
# occupation
# relationship
# race
# gender
# capital-gain
# capital-loss
# hours-per-week
# native-country
# income

# %%
# Use for identifying all distinct ages in the dataset without duplicates
df['age'].unique()
# Out:
# array([25, 38, 28, 44, 18, 34, 29, 63, 24, 55, 65, 36, 26, 58, 48, 43, 20,
#        37, 40, 72, 45, 22, 23, 54, 32, 46, 56, 17, 39, 52, 21, 42, 33, 30,
#        47, 41, 19, 69, 50, 31, 59, 49, 51, 27, 57, 61, 64, 79, 73, 53, 77,
#        80, 62, 35, 68, 66, 75, 60, 67, 71, 70, 90, 81, 74, 78, 82, 83, 85,
#        76, 84, 89, 88, 87, 86], dtype=int64)

# %%
# Use for uniqueness and variety of data across different columns
df.nunique()
# Out:
# age                   74
# workclass              9
# fnlwgt             28523
# education             16
# educational-num       16
# marital-status         7
# occupation            15
# relationship           6
# race                   5
# gender                 2
# capital-gain         123
# capital-loss          99
# hours-per-week        96
# native-country        42
# income                 2
# dtype: int64
